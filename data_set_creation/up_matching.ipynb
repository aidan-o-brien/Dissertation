# %% [markdown]
# # Purpose
#
# Upload.

# %% [markdown]
# # Import dependencies

# %%
import pandas as pd
import numpy as np
import os
from fuzzywuzzy import fuzz, process
from rapidfuzz import process as faster_process
from datetime import datetime, timedelta
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import requests
import chwrapper
import json
import ast
# Out:
# C:\Users\aidan\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Load data

# %%
def load_grid_data(cleaning=False):
    
    os.chdir(os.getcwd() + '\\grid')
    
    institutes_df = pd.read_csv('grid.csv').rename(columns={'ID': 'grid_id'})
    type_df = pd.read_csv('types.csv')
    address_df = pd.read_csv('addresses.csv', usecols=['grid_id', 'lat', 'lng', 'city'])
    #acronyms_df = pd.read_csv('acronyms.csv')
    
    # Filter for only UK companies
    uk_institutes_df = institutes_df[institutes_df['Country'] == 'United Kingdom']
    
    # Join data frames
    merged_df = pd.merge(uk_institutes_df, type_df, on='grid_id', how='left')
    merged_df = pd.merge(merged_df, address_df, on='grid_id', how='left')
    
    if cleaning:
        print(merged_df.shape[0])
        merged_df = pd.merge(merged_df, pd.read_csv('institutes.csv'), on='grid_id', how='left')
        print(merged_df.shape[0])
        return merged_df
    
    return merged_df

# %%
def load_scopus_affils():
    os.chdir('..')
    df = pd.read_csv('scopus_uk_affils.csv').drop(columns=['Unnamed: 0'])
    return df

# %%
grid_df = load_grid_data()
scopus_affils_df = load_scopus_affils()

# %% [markdown]
# # Prepare Scopus and GRID data for matching

# %%
# If GRID name includes (United Kingdom), remove it
uk = '(United Kingdom)'
grid_df['formatted_name'] = grid_df['Name'].apply(lambda x: x.replace(uk, '') if uk in x else x)

# %% [markdown]
# # fuzzywuzzy
#
# Fuzzywuzzy is the pure Python implementation whereas rapidfuzz is implemented in C++ for significant speed improvements. Fuzzywuzzy has four main functionalities: `partial_ratio`, `ratio`, `token_sort_ratio` and `token_set_ratio`. Rapidfuzz has this functionality and more!

# %%
str_1 = 'Howdie partner, how are you today?'
str_2 = 'how are you today partner?'
print(fuzz.partial_ratio(str_1, str_2))
print(fuzz.ratio(str_1, str_2))

# Token methods pre-process the strings by converting to lower case, removing punctuation
# and tokenising. Next, the tokens are sorted alphabetically and then joined together.
# fuzz.ratio() is then called on the resulting string.
print(fuzz.token_sort_ratio(str_1, str_2))

# Takes a set of the intersection and then makes pairwise comparisons using fuzz.ratio()
# The logic here is that ____
print(fuzz.token_set_ratio(str_1, str_2))
# Out:
# 82
# 60
# 88
# 100

# %%
str_3 = 'Are you ok today partner?'
str_4 = 'Good morning, how are you?'
print(f'Original phrase: {str_1}')
print(process.extract(str_1, [str_2, str_3, str_4]))
# Out:
# Original phrase: Howdie partner, how are you today?
# [('how are you today partner?', 95), ('Are you ok today partner?', 88), ('Good morning, how are you?', 60)]

# %% [markdown]
# # Match Scopus against GRID
#
# __Scopus data:__
#
# There are 48060 affiliations. 45132 of those do not have an affiliation type associated with it.
#
# Of the 45132 affiliations without an affiliation type:
#
# * 11117 of them do not have an address or post code associated with them from Scopus
# * 5426 of them have an address but not a post code
# * 2652 of them have a post code but no address
#
# __What data do we have to match?__
#
# * Scopus `affil_name` against GRID `formatted_name`
# * Scopus `affil_name` agaisnt Companies House `CompanyName` and `PreviousName_<number>.CompanyName`
# * Scopus `post_code` against GRID
# * Scopus `post_code` against Companies House `RegAddress.PostCode`

# %%
# Add the method for finding affil_type
# Confidence not used anymore but I don't want to misalign any columns so keeping it
add_type_source = lambda x: 'scopus' if pd.notnull(x) else np.nan
scopus_confidence = lambda x: 10 if x == 'scopus' else 0
scopus_affils_df['type_source'] = scopus_affils_df['affil_type'].apply(add_type_source)
scopus_affils_df['type_confidence'] = scopus_affils_df['type_source'].apply(scopus_confidence)

# %%
# How long will fuzzy matching take?
grid_l = grid_df.formatted_name.to_list()
fuzzy_match = lambda x: faster_process.extract(x, grid_l)
% timeit fuzzy_match('Newcastle University')
# Out:
# 70.2 ms ± 6.19 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
0.07 * 48000 / 60
# Out:
# 56.00000000000001

# %%
# Fuzzy match Scopus affil_name against GRID formatted_name - ROUGHLY ONE HOUR PROCESSING TIME
grid_l = grid_df.formatted_name.to_list()
fuzzy_match = lambda x: faster_process.extract(x, grid_l)
scopus_affils_df['grid_name_matches'] = scopus_affils_df.affil_name.apply(fuzzy_match)

# %%
# Find best scores and matches from fuzzy matching
find_best_score = lambda x: x[0][1]
find_best_match = lambda x: x[0][0]
scopus_affils_df['grid_name_best_score'] = scopus_affils_df['grid_name_matches'].apply(find_best_score)
scopus_affils_df['grid_name_best_match'] = scopus_affils_df['grid_name_matches'].apply(find_best_match)

# %%
scopus_affils_df[scopus_affils_df['grid_name_best_score'] > 90].shape[0]
# Out:
# 4397

# %% [markdown]
# # Geocoding with geopy

# %%
geolocator = Nominatim(user_agent='dissertation_data_prep')

# %%
bath_location = geolocator.geocode('University of Bath')

# %%
print('Example information that can be found using geopy:')
for k, v in bath_location.raw.items():
    print(f'{k}:')
    print(v)
# Out:
# Example information that can be found using geopy:
# place_id:
# 172212413
# licence:
# Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright
# osm_type:
# way
# osm_id:
# 345133857
# boundingbox:
# ['51.3711087', '51.3822835', '-2.3356602', '-2.3168895']
# lat:
# 51.37658545
# lon:
# -2.323423021360605
# display_name:
# University of Bath, All Saints Place, Claverton Down, Bath, Bath and North East Somerset, South West England, England, BA2 6DU, United Kingdom
# class:
# amenity
# type:
# university
# importance:
# 0.7921407251596808
# icon:
# https://nominatim.openstreetmap.org/ui/mapicons//education_university.p.20.png

# %%
bath_ll = (bath_location.longitude, bath_location.latitude)
spa_location = geolocator.geocode('Bath Spa University')
spa_ll = (spa_location.longitude, spa_location.latitude)

# %%
print('You can even calculate the distance between two (lng, lat) tuples.')
geodesic(bath_ll, spa_ll).km
# Out:
# You can even calculate the distance between two (lng, lat) tuples.
# 12.749361491893458

# %% [markdown]
# # Geocoding with a database
#
# This means that we don't have to worry about the rate limit on the geopy.
#
# * 16543 post code is null
# * 31517 post code is not null

# %%
def load_post_code_data():
    os.chdir(os.getcwd() + '\\uk_post_codes')
    df = pd.read_csv('ukpostcodes.csv')
    return df

post_code_df = load_post_code_data()

# %%
def geocode(x):
    
    # If there is a postcode in scopus df
    if pd.notnull(x):
        # Search for post code in post code df
        row = post_code_df[post_code_df['postcode'] == x]
        # If the post code is not in the post code df, return nan
        if row.shape[0] == 0:
            return np.nan
        else:
            return (row['latitude'].values[0], row['longitude'].values[0])
    # If no post code in scopus df > return nan
    else:
        return np.nan
    

scopus_affils_df['lat_lng'] = scopus_affils_df['post_code'].apply(geocode)

# %%
# Re-shuffle data frame to get lat_lng after post_code
columns = list(scopus_affils_df.columns)
columns.remove('lat_lng')
columns.insert(5, 'lat_lng')
scopus_affils_df = scopus_affils_df.reindex(columns=columns)
scopus_affils_df.head(1)
# Out:
#       af_id          affil_name affil_city   affil_address post_code  \
# 0  60030480  University of Bath       Bath  Claverton Down   BA2 7AY
#
#                  lat_lng affil_type type_source  type_confidence  \
# 0  (51.38044, -2.330673)       univ      scopus               10
#
#                                    grid_name_matches  grid_name_best_score  \
# 0  [(University of Bath, 100.0, 48), (Bath Spa Un...                 100.0
#
#   grid_name_best_match  grid_best_match_distance_km
# 0   University of Bath                          NaN

# %%
def find_best_grid_match_distance(df):
    
    df['grid_best_match_distance_km'] = np.nan
    
    for i, row in df.iterrows():
        
        #if row['type_source'] != 'scopus':
        if pd.notnull(row['lat_lng']):

            grid_match = row['grid_name_best_match']
            grid_row = grid_df[grid_df['formatted_name'] == f'{grid_match}']
            grid_lat_lng = (grid_row['lat'].values[0], grid_row['lng'].values[0])

            if pd.notnull(grid_lat_lng):
                try:
                    df.iloc[i, 12] = geodesic(row['lat_lng'], grid_lat_lng).km
                except:
                    print('Error found on index:', i)
                    print('Scopus row:\n', row['lat_lng'])
                    print('GRID row:\n', grid_lat_lng)
            else:
                print(grid_row)
                print('Scopus lat lng:', row['lat_lng'])
                print('GRID lat lng:', grid_lat_lng)
                df.iloc[i, 11] = np.nan

        else:
            df.iloc[i, 12] = np.nan
            
    return df


scopus_affils_df = find_best_grid_match_distance(scopus_affils_df)
# Out:
# Error found on index: 405
# Scopus row:
#  (54.530374, -1.563733)
# GRID row:
#  (nan, nan)
# Error found on index: 479
# Scopus row:
#  (53.408494, -2.9675689999999997)
# GRID row:
#  (nan, nan)
# Error found on index: 543
# Scopus row:
#  (52.231660999999995, 0.709176)
# GRID row:
#  (nan, nan)
# Error found on index: 791
# Scopus row:
#  (51.403328, 0.02412)
# GRID row:
#  (nan, nan)
# Error found on index: 818
# Scopus row:
#  (51.458611, -2.595196)
# GRID row:
#  (nan, nan)
# C:\Users\aidan\Anaconda3\lib\site-packages\geopy\point.py:472: UserWarning: Latitude normalization has been prohibited in the newer versions of geopy, because the normalized value happened to be on a different pole, which is probably not what was meant. If you pass coordinates as positional args, please make sure that the order is (latitude, longitude) or (y, x) in Cartesian terms.
#   return cls(*args)
# Error found on index: 974
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.588108, -0.666981)
# Error found on index: 1124
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.992582999999996, -1.542993)
# Error found on index: 1148
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.503360014460704, -0.0871449708938599)
# Error found on index: 1228
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.931689, -1.784703)
# Error found on index: 1369
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.324496999999994, -2.694013)
# Error found on index: 1430
# Scopus row:
#  (51.494417999999996, -3.2264180000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 1953
# Scopus row:
#  (51.540636, -0.665563)
# GRID row:
#  (nan, nan)
# Error found on index: 1999
# Scopus row:
#  (53.374345999999996, -1.5173219999999998)
# GRID row:
#  (nan, nan)
# Error found on index: 2456
# Scopus row:
#  (51.369069, -0.781)
# GRID row:
#  (nan, nan)
# Error found on index: 2568
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (55.944894999999995, -3.1892840000000002)
# Error found on index: 2745
# Scopus row:
#  (53.721586, -2.74383)
# GRID row:
#  (nan, nan)
# Error found on index: 2900
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.60623, -0.41678999999999994)
# Error found on index: 3020
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.495712, -0.126351)
# Error found on index: 3212
# Scopus row:
#  (51.752617, -1.2150889999999999)
# GRID row:
#  (nan, nan)
# Error found on index: 3809
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.705985999999996, -3.530994)
# Error found on index: 4875
# Scopus row:
#  (51.39229, -2.3866810000000003)
# GRID row:
#  (nan, nan)
# Error found on index: 5731
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.364408000000005, -4.139501)
# Error found on index: 6701
# Scopus row:
#  (51.872487, -1.483491)
# GRID row:
#  (nan, nan)
# Error found on index: 6830
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.441123, 1.727375)
# Error found on index: 6943
# Scopus row:
#  (51.761813000000004, -0.552824)
# GRID row:
#  (nan, nan)
# Error found on index: 7504
# Scopus row:
#  (51.612043, 0.027556)
# GRID row:
#  (nan, nan)
# Error found on index: 7510
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.500209999999996, -2.5474900000000003)
# Error found on index: 7754
# Scopus row:
#  (51.483162, -3.173253)
# GRID row:
#  (nan, nan)
# Error found on index: 8040
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.417812, -4.110435)
# Error found on index: 8083
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.514181, -0.11772)
# Error found on index: 8141
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.514181, -0.11772)
# Error found on index: 8344
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.421201, -1.438976)
# Error found on index: 8732
# Scopus row:
#  (51.337163000000004, -0.704024)
# GRID row:
#  (nan, nan)
# Error found on index: 9105
# Scopus row:
#  (51.586164000000004, -0.142604)
# GRID row:
#  (nan, nan)
# Error found on index: 9511
# Scopus row:
#  (52.245425, -0.845966)
# GRID row:
#  (nan, nan)
# Error found on index: 9792
# Scopus row:
#  (52.180015000000004, 1.579465)
# GRID row:
#  (nan, nan)
# Error found on index: 11048
# Scopus row:
#  (53.606501, -2.167505)
# GRID row:
#  (nan, nan)
# Error found on index: 12250
# Scopus row:
#  (51.201658, -0.794899)
# GRID row:
#  (nan, nan)
# Error found on index: 12669
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.009723, -2.181264)
# Error found on index: 12800
# Scopus row:
#  (51.551214, 0.6600729999999999)
# GRID row:
#  (nan, nan)
# Error found on index: 12865
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.324496999999994, -2.694013)
# Error found on index: 12912
# Scopus row:
#  (51.463896000000005, -0.11405799999999999)
# GRID row:
#  (nan, nan)
# Error found on index: 13002
# Scopus row:
#  (53.157309999999995, -1.190733)
# GRID row:
#  (nan, nan)
# Error found on index: 13008
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.933, -1.4340000000000002)
# Error found on index: 13030
# Scopus row:
#  (51.533015, -0.133205)
# GRID row:
#  (nan, nan)
# Error found on index: 13317
# Scopus row:
#  (51.800831, -0.215986)
# GRID row:
#  (nan, nan)
# Error found on index: 13394
# Scopus row:
#  (55.94453299999999, -3.197082)
# GRID row:
#  (nan, nan)
# Error found on index: 13555
# Scopus row:
#  (51.687542, -1.705432)
# GRID row:
#  (nan, nan)
# Error found on index: 13639
# Scopus row:
#  (52.026156, -0.49336499999999994)
# GRID row:
#  (nan, nan)
# Error found on index: 13961
# Scopus row:
#  (52.836227, -1.275938)
# GRID row:
#  (nan, nan)
# Error found on index: 13977
# Scopus row:
#  (53.131322999999995, -1.2163760000000001)
# GRID row:
#  (nan, nan)
# Error found on index: 14566
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.223108, -2.3272049999999997)
# Error found on index: 14879
# Scopus row:
#  (55.867026, -4.272995)
# GRID row:
#  (nan, nan)
# Error found on index: 15512
# Scopus row:
#  (52.095855, -2.959738)
# GRID row:
#  (nan, nan)
# Error found on index: 15615
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (54.584596, -5.93406)
# Error found on index: 16420
# Scopus row:
#  (52.556839000000004, -1.8244490000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 16525
# Scopus row:
#  (52.129671, -1.056449)
# GRID row:
#  (nan, nan)
# Error found on index: 17368
# Scopus row:
#  (51.561234999999996, -0.399266)
# GRID row:
#  (nan, nan)
# Error found on index: 17376
# Scopus row:
#  (52.086346, -0.2567)
# GRID row:
#  (nan, nan)
# Error found on index: 17419
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.441123, 1.727375)
# Error found on index: 17708
# Scopus row:
#  (51.357078, -0.21664699999999998)
# GRID row:
#  (nan, nan)
# Error found on index: 17823
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.355197, -0.09312100000000001)
# Error found on index: 18108
# Scopus row:
#  (51.398819, -0.9711059999999999)
# GRID row:
#  (nan, nan)
# Error found on index: 18371
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.421201, -1.438976)
# Error found on index: 18486
# Scopus row:
#  (51.604812, -2.523898)
# GRID row:
#  (nan, nan)
# Error found on index: 18546
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.190121999999995, 0.128301)
# Error found on index: 18547
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.53095, -3.087991)
# Error found on index: 18640
# Scopus row:
#  (54.778034999999996, -1.596349)
# GRID row:
#  (nan, nan)
# Error found on index: 18734
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.514934000000004, -0.06744299999999999)
# Error found on index: 18828
# Scopus row:
#  (51.465498, -2.619642)
# GRID row:
#  (nan, nan)
# Error found on index: 18937
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.495712, -0.126351)
# Error found on index: 19129
# Scopus row:
#  (51.341260999999996, -0.266336)
# GRID row:
#  (nan, nan)
# Error found on index: 19782
# Scopus row:
#  (53.4972, -1.317657)
# GRID row:
#  (nan, nan)
# Error found on index: 19978
# Scopus row:
#  (53.423787, -2.244584)
# GRID row:
#  (nan, nan)
# Error found on index: 20042
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.510923, -0.142087)
# Error found on index: 20057
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.945703, -1.056188)
# Error found on index: 20172
# Scopus row:
#  (51.764885, -1.2701440000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 20278
# Scopus row:
#  (53.003903, -2.271647)
# GRID row:
#  (nan, nan)
# Error found on index: 20287
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.324496999999994, -2.694013)
# Error found on index: 20330
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.324496999999994, -2.694013)
# Error found on index: 20492
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.355197, -0.09312100000000001)
# Error found on index: 20572
# Scopus row:
#  (55.926784, -3.170255)
# GRID row:
#  (nan, nan)
# Error found on index: 20632
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.190121999999995, 0.128301)
# Error found on index: 20651
# Scopus row:
#  (51.100766, -1.706331)
# GRID row:
#  (nan, nan)
# Error found on index: 21079
# Scopus row:
#  (57.008821, -4.25301)
# GRID row:
#  (nan, nan)
# Error found on index: 21083
# Scopus row:
#  (52.656940000000006, -2.523072)
# GRID row:
#  (nan, nan)
# Error found on index: 21176
# Scopus row:
#  (51.410996000000004, -0.20064500000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 21207
# Scopus row:
#  (53.72673, -1.721848)
# GRID row:
#  (nan, nan)
# Error found on index: 21794
# Scopus row:
#  (52.545867, -1.827884)
# GRID row:
#  (nan, nan)
# Error found on index: 22262
# Scopus row:
#  (53.554145, -2.010332)
# GRID row:
#  (nan, nan)
# Error found on index: 22686
# Scopus row:
#  (51.648618, -0.19579100000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 22920
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.516241, -0.098028)
# Error found on index: 23359
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.521111, -0.128889)
# Error found on index: 23477
# Scopus row:
#  (51.48791, -0.089272)
# GRID row:
#  (nan, nan)
# Error found on index: 23680
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.442108000000005, -0.154569)
# Error found on index: 23758
# Scopus row:
#  (51.280638, 0.49673999999999996)
# GRID row:
#  (nan, nan)
# Error found on index: 24157
# Scopus row:
#  (51.532369, -0.09919)
# GRID row:
#  (nan, nan)
# Error found on index: 24316
# Scopus row:
#  (51.435761, -0.223584)
# GRID row:
#  (nan, nan)
# Error found on index: 24337
# Scopus row:
#  (53.399621999999994, -2.974211)
# GRID row:
#  (nan, nan)
# Error found on index: 24342
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.495712, -0.126351)
# Error found on index: 24531
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.324496999999994, -2.694013)
# Error found on index: 24994
# Scopus row:
#  (51.685194, -2.301473)
# GRID row:
#  (nan, nan)
# Error found on index: 25344
# Scopus row:
#  (51.940166, -3.254311)
# GRID row:
#  (nan, nan)
# Error found on index: 25404
# Scopus row:
#  (51.521673, -3.5826300000000004)
# GRID row:
#  (nan, nan)
# Error found on index: 25852
# Scopus row:
#  (52.487588, -1.911994)
# GRID row:
#  (nan, nan)
# Error found on index: 26001
# Scopus row:
#  (56.386062, -3.4405879999999995)
# GRID row:
#  (nan, nan)
# Error found on index: 26324
# Scopus row:
#  (52.580760999999995, -1.8304630000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 26379
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.514181, -0.11772)
# Error found on index: 26601
# Scopus row:
#  (51.465942999999996, -0.291589)
# GRID row:
#  (nan, nan)
# Error found on index: 26654
# Scopus row:
#  (55.969333, -3.622093)
# GRID row:
#  (nan, nan)
# Error found on index: 27380
# Scopus row:
#  (51.519391, -0.106303)
# GRID row:
#  (nan, nan)
# Error found on index: 27518
# Scopus row:
#  (51.546186, -0.17848699999999998)
# GRID row:
#  (nan, nan)
# Error found on index: 27738
# Scopus row:
#  (52.259747999999995, 0.395563)
# GRID row:
#  (nan, nan)
# Error found on index: 27793
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.175276000000004, 0.133323)
# Error found on index: 27816
# Scopus row:
#  (52.288199, -1.5358049999999999)
# GRID row:
#  (nan, nan)
# Error found on index: 28012
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.4328, -0.3078)
# Error found on index: 28117
# Scopus row:
#  (51.41084, -0.293587)
# GRID row:
#  (nan, nan)
# Error found on index: 28260
# Scopus row:
#  (56.461679000000004, -2.991415)
# GRID row:
#  (nan, nan)
# Error found on index: 28531
# Scopus row:
#  (51.508205, -0.14239000000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 28537
# Scopus row:
#  (53.663332999999994, -1.5037530000000001)
# GRID row:
#  (nan, nan)
# Error found on index: 28615
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.49100000000001, -0.127)
# Error found on index: 28684
# Scopus row:
#  (51.341260999999996, -0.266336)
# GRID row:
#  (nan, nan)
# Error found on index: 28808
# Scopus row:
#  (52.237252000000005, -0.900552)
# GRID row:
#  (nan, nan)
# Error found on index: 29651
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.519482, -3.7484040000000003)
# Error found on index: 29941
# Scopus row:
#  (51.448024, -0.061103)
# GRID row:
#  (nan, nan)
# Error found on index: 30122
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.541835, -0.07574299999999999)
# Error found on index: 30310
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.261932, 1.084964)
# Error found on index: 30485
# Scopus row:
#  (51.042653, -3.3115059999999996)
# GRID row:
#  (nan, nan)
# Error found on index: 30669
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.514934000000004, -0.06744299999999999)
# Error found on index: 31716
# Scopus row:
#  (51.73301, -1.984879)
# GRID row:
#  (nan, nan)
# Error found on index: 31737
# Scopus row:
#  (52.393921999999996, 0.24687800000000001)
# GRID row:
#  (nan, nan)
# Error found on index: 32482
# Scopus row:
#  (52.622085999999996, -1.124531)
# GRID row:
#  (nan, nan)
# Error found on index: 33188
# Scopus row:
#  (51.369069, -0.781)
# GRID row:
#  (nan, nan)
# Error found on index: 33247
# Scopus row:
#  (51.454237, -2.592476)
# GRID row:
#  (nan, nan)
# Error found on index: 33412
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.79756, -2.250022)
# Error found on index: 33472
# Scopus row:
#  (52.771483999999994, -2.87316)
# GRID row:
#  (nan, nan)
# Error found on index: 33522
# Scopus row:
#  (51.450215, -2.6139959999999998)
# GRID row:
#  (nan, nan)
# Error found on index: 33537
# Scopus row:
#  (54.56890500000001, -1.353499)
# GRID row:
#  (nan, nan)
# Error found on index: 33560
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.566957, -1.785321)
# Error found on index: 33618
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (54.851085999999995, -1.575045)
# Error found on index: 33963
# Scopus row:
#  (52.497613, -1.881527)
# GRID row:
#  (nan, nan)
# Error found on index: 34085
# Scopus row:
#  (52.476335, -0.903158)
# GRID row:
#  (nan, nan)
# Error found on index: 34313
# Scopus row:
#  (51.546991999999996, -0.141878)
# GRID row:
#  (nan, nan)
# Error found on index: 34386
# Scopus row:
#  (51.814689, -0.346503)
# GRID row:
#  (nan, nan)
# Error found on index: 34474
# Scopus row:
#  (53.344517, -1.507581)
# GRID row:
#  (nan, nan)
# Error found on index: 34931
# Scopus row:
#  (51.478171, -0.994641)
# GRID row:
#  (nan, nan)
# Error found on index: 35110
# Scopus row:
#  (52.457094, -1.217638)
# GRID row:
#  (nan, nan)
# Error found on index: 35942
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.324496999999994, -2.694013)
# Error found on index: 36188
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.705985999999996, -3.530994)
# Error found on index: 36205
# Scopus row:
#  (50.838873, -0.134866)
# GRID row:
#  (nan, nan)
# Error found on index: 36330
# Scopus row:
#  (54.313343999999994, -2.968498)
# GRID row:
#  (nan, nan)
# Error found on index: 36355
# Scopus row:
#  (53.463186, -2.2299439999999997)
# GRID row:
#  (nan, nan)
# Error found on index: 37462
# Scopus row:
#  (51.313277, 0.43438000000000004)
# GRID row:
#  (nan, nan)
# Error found on index: 38025
# Scopus row:
#  (52.089492, 1.261034)
# GRID row:
#  (nan, nan)
# Error found on index: 38027
# Scopus row:
#  (51.453258, -0.112899)
# GRID row:
#  (nan, nan)
# Error found on index: 38172
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.441123, 1.727375)
# Error found on index: 38216
# Scopus row:
#  (53.85411, -1.836495)
# GRID row:
#  (nan, nan)
# Error found on index: 38421
# Scopus row:
#  (52.225002, -0.548822)
# GRID row:
#  (nan, nan)
# Error found on index: 38545
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.99822, -2.111607)
# Error found on index: 38705
# Scopus row:
#  (52.095855, -2.959738)
# GRID row:
#  (nan, nan)
# Error found on index: 38998
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (50.360175, -4.745919000000001)
# Error found on index: 39285
# Scopus row:
#  (51.502617, -0.016929)
# GRID row:
#  (nan, nan)
# Error found on index: 39704
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.492567, -2.783016)
# Error found on index: 40039
# Scopus row:
#  (51.405424, -0.971709)
# GRID row:
#  (nan, nan)
# Error found on index: 40157
# Scopus row:
#  (51.509302000000005, -0.134967)
# GRID row:
#  (nan, nan)
# Error found on index: 40264
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.175276000000004, 0.133323)
# Error found on index: 40626
# Scopus row:
#  (50.847592999999996, -1.168168)
# GRID row:
#  (nan, nan)
# Error found on index: 40866
# Scopus row:
#  (51.526253999999994, -0.109118)
# GRID row:
#  (nan, nan)
# Error found on index: 41021
# Scopus row:
#  (55.888699, -3.618119)
# GRID row:
#  (nan, nan)
# Error found on index: 41045
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.453187, -2.609557)
# Error found on index: 41100
# Scopus row:
#  (51.479456, -0.188937)
# GRID row:
#  (nan, nan)
# Error found on index: 41105
# Scopus row:
#  (51.516631, -0.130055)
# GRID row:
#  (nan, nan)
# Error found on index: 41326
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (53.447846999999996, -2.991963)
# Error found on index: 41925
# Scopus row:
#  (51.334344, -0.72654)
# GRID row:
#  (nan, nan)
# Error found on index: 42311
# Scopus row:
#  (53.641053, -1.329012)
# GRID row:
#  (nan, nan)
# Error found on index: 42448
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (55.944894999999995, -3.1892840000000002)
# Error found on index: 42647
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.441123, 1.727375)
# Error found on index: 43060
# Scopus row:
#  (51.331115000000004, -0.701137)
# GRID row:
#  (nan, nan)
# Error found on index: 43511
# Scopus row:
#  (51.481873, -3.172396)
# GRID row:
#  (nan, nan)
# Error found on index: 43549
# Scopus row:
#  (51.457817999999996, -2.597301)
# GRID row:
#  (nan, nan)
# Error found on index: 43821
# Scopus row:
#  (51.512097, -0.139106)
# GRID row:
#  (nan, nan)
# Error found on index: 43897
# Scopus row:
#  (51.278595, -0.8474700000000001)
# GRID row:
#  (nan, nan)
# Error found on index: 44165
# Scopus row:
#  (51.465831, -3.167061)
# GRID row:
#  (nan, nan)
# Error found on index: 44268
# Scopus row:
#  (51.071202, -1.350085)
# GRID row:
#  (nan, nan)
# Error found on index: 44520
# Scopus row:
#  (54.49006800000001, -2.3370509999999998)
# GRID row:
#  (nan, nan)
# Error found on index: 44725
# Scopus row:
#  (51.025058, -0.340317)
# GRID row:
#  (nan, nan)
# Error found on index: 44812
# Scopus row:
#  (51.803247999999996, -1.920667)
# GRID row:
#  (nan, nan)
# Error found on index: 45039
# Scopus row:
#  (53.649283999999994, -1.7804650000000002)
# GRID row:
#  (nan, nan)
# Error found on index: 45338
# Scopus row:
#  (54.807044999999995, -1.777852)
# GRID row:
#  (nan, nan)
# Error found on index: 45586
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.190121999999995, 0.128301)
# Error found on index: 45667
# Scopus row:
#  (57.144351, -2.107627)
# GRID row:
#  (nan, nan)
# Error found on index: 45964
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.223108, -2.3272049999999997)
# Error found on index: 46154
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.505289000000005, -0.10880799999999999)
# Error found on index: 46377
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.507569000000004, -3.192557)
# Error found on index: 46386
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (52.441123, 1.727375)
# Error found on index: 46415
# Scopus row:
#  (50.634462, -4.356684)
# GRID row:
#  (nan, nan)
# Error found on index: 46453
# Scopus row:
#  (53.743788, -2.9886310000000003)
# GRID row:
#  (nan, nan)
# Error found on index: 47057
# Scopus row:
#  (51.505439, -0.08446000000000001)
# GRID row:
#  (nan, nan)
# Error found on index: 47294
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (56.321167, -3.010374)
# Error found on index: 47401
# Scopus row:
#  (99.999999, 0.0)
# GRID row:
#  (51.499715, -0.286517)
# Error found on index: 47438
# Scopus row:
#  (51.512492, -3.5046209999999998)
# GRID row:
#  (nan, nan)
# Error found on index: 47460
# Scopus row:
#  (53.46400799999999, -2.228126)
# GRID row:
#  (nan, nan)

# %%
# There seem to be some rows that have a post code but no lat_lng
# Why is this happening?
# Some of the GRID institutes do not have lat and lng!
scopus_affils_df
# Out:
#            af_id                        affil_name  affil_city  \
# 0       60030480                University of Bath        Bath
# 1       60022871                St Mary's Hospital      London
# 2       60022148         University College London      London
# 3       60011520             King's College London      London
# 4       60003771      The University of Manchester  Manchester
# ...          ...                               ...         ...
# 48055  108616326          Lntervet Innovation GmbH         NaN
# 48056  107918540           Conder Brow Observatory   Lancaster
# 48057  106599190                  Starlight Xpress   Berkshire
# 48058  106598998  British Astronomical Association     Reading
# 48059  106598714        Simoco Digital Systems Ltd   Cambridge
#
#                                            affil_address post_code  \
# 0                                         Claverton Down   BA2 7AY
# 1                                           Praed Street    W2 1NY
# 2                                           Gower Street  WC1E 6BT
# 3                                                 Strand  WC2R 2LS
# 4                                            Oxford Road   M13 9PL
# ...                                                  ...       ...
# 48055                                       Schwabenheim       NaN
# 48056  Fell Acre, Conder Brow, Little Fell Lane, Scot...   LAI 1XD
# 48057            Foxley Green Farm, Ascot Road, Holyport   SL6 3LA
# 48058                                       Lower Earley   RG6 4AZ
# 48059                       Radio House, St Andrews Road   CB4 1GR
#
#                                  lat_lng affil_type type_source  \
# 0                  (51.38044, -2.330673)       univ      scopus
# 1                 (51.516969, -0.173569)       hosp      scopus
# 2      (51.523569, -0.13242400000000001)       univ      scopus
# 3                 (51.511612, -0.116253)       univ      scopus
# 4       (53.467925, -2.2332240000000003)       univ      scopus
# ...                                  ...        ...         ...
# 48055                                NaN        NaN         NaN
# 48056                                NaN        NaN         NaN
# 48057             (51.483702, -0.733949)        NaN         NaN
# 48058              (51.420429, -0.94514)        NaN         NaN
# 48059                                NaN        NaN         NaN
#
#        type_confidence                                  grid_name_matches  \
# 0                   10  [(University of Bath, 100.0, 48), (Bath Spa Un...
# 1                   10  [(St Mary's Hospital, 100.0, 570), (St Mary's ...
# 2                   10  [(University College London, 100.0, 218), (Uni...
# 3                   10  [(King's College London, 100.0, 100), (Royal H...
# 4                   10  [(University of Manchester, 95.0, 31), (Univer...
# ...                ...                                                ...
# 48055                0  [(Kite Innovation , 85.5, 1905), (Nonwovens In...
# 48056                0  [(Infectious Diseases Data Observatory, 85.5, ...
# 48057                0  [(Esys , 77.14285714285714, 1717), (Start, 72....
# 48058                0  [(British Astronomical Association, 100.0, 714...
# 48059                0  [(BAE Systems , 85.5, 4), (UK Intelligent Syst...
#
#        grid_name_best_score                  grid_name_best_match  \
# 0                100.000000                    University of Bath
# 1                100.000000                    St Mary's Hospital
# 2                100.000000             University College London
# 3                100.000000                 King's College London
# 4                 95.000000              University of Manchester
# ...                     ...                                   ...
# 48055             85.500000                      Kite Innovation
# 48056             85.500000  Infectious Diseases Data Observatory
# 48057             77.142857                                 Esys
# 48058            100.000000      British Astronomical Association
# 48059             85.500000                          BAE Systems
#
#        grid_best_match_distance_km
# 0                         0.208249
# 1                       257.163038
# 2                         0.147594
# 3                         0.039293
# 4                         0.106995
# ...                            ...
# 48055                          NaN
# 48056                          NaN
# 48057                    28.117923
# 48058                    56.849778
# 48059                          NaN
#
# [48060 rows x 13 columns]

# %%
# Add fuzzy GRID matches affil_type and type_source
def nearest_inst_type(scopus_row, grid_rows):
    '''
    Input:
    - scopus row: one row of the scopus
    - grid_rows: one or more rows of the grid_df
    Returns:
    - dictionary containing closest distance, type and grid id
    Notes: 
    - scopus['grid_name_best_match'] == grid['formatted_name']
    - function will return np.nan for distance and type if not suitable
    '''
    
    closest = {'distance': np.inf,
               'type': np.nan,
               'grid_id': np.nan}
    
    # Only one proposal > return proposal irrespective of distance
    if grid_rows.shape[0] == 1:
        closest['type'] = grid_rows['type'].values[0]
        closest['grid_id'] = grid_rows['grid_id'].values[0]
        return closest
    # More than one proposal > check which is closest in distance
    # If Scopus row does not have lat_lng > return np.nan for type and grid_id
    elif pd.isnull(scopus_row['lat_lng']):
        return closest
    
    # Multiple proposals to consider
    for i, row in grid_rows.iterrows():
        
        grid_lat_lng = (row['lat'], row['lng'])
        
        # If the grid proposal does not have lng, lat data, skip to next proposal
        if pd.isnull(grid_lat_lng[0]):
            continue
        distance = geodesic(grid_lat_lng, scopus_row['lat_lng'])
        if distance < closest['distance']:
            closest['distance'] = distance
            closest['type'] = row['type']
            closest['grid_id'] = row['grid_id']
    
    return closest


def add_fuzzy_grid_info(df):
    
    df['grid_id_match'] = None
    
    for i, row in df.iterrows():
        
        # If the affiliation does not have a type yet
        #if pd.isnull(row['type_source']):
            
        proposed_name = row['grid_name_best_match']
        grid_data = grid_df[grid_df['formatted_name'] == f'{proposed_name}']

        # Exact matching
        if row['grid_name_best_score'] == 100:
            closest = nearest_inst_type(row, grid_data)
            df.iloc[i, 6] = closest['type'] # nan or type
            df.iloc[i, 13] = closest['grid_id'] # nan or distance
            # Only update type_source if there is a match
            if pd.notnull(closest['type']):
                df.iloc[i, 7] = 'exact_grid'
        # Fuzzy matching
        elif row['grid_name_best_score'] > 91:
            closest = nearest_inst_type(row, grid_data)
            df.iloc[i, 6] = closest['type']
            df.iloc[i, 13] = closest['grid_id']
            if pd.notnull(closest['type']):
                df.iloc[i, 7] = 'fuzzy_grid'
        #else:
            #continue
    
    return df


scopus_affils_df = add_fuzzy_grid_info(scopus_affils_df)

# %%
def add_more_fuzzy_grid_info(df):
    '''This function is used to add fuzzy match info for affiliations that:
    - Have a fuzzy score >= 90 AND
    - Are located within 2 km of their match
    '''
    
    for i, row in df.iterrows():
        
        # If the affiliation does not have a type yet
        # For some reason, this didn't work for grid_id so had to use the commented out row
        if pd.isnull(row['type_source']):
        #if row['type_source'] == 'fuzzy_loc_grid':
            
            proposed_name = row['grid_name_best_match']
            grid_data = grid_df[grid_df['formatted_name'] == f'{proposed_name}']

            if (row['grid_name_best_score'] >= 90) and (row['grid_best_match_distance_km'] < 2):
                closest = nearest_inst_type(row, grid_data)
                df.iloc[i, 6] = closest['type'] # nan or type
                #print(closest['grid_id'])
                df.iloc[i, 13] = closest['grid_id'] # nan or grid_id
                df.iloc[i, 7] = 'fuzzy_loc_grid'
            else:
                continue
    
    return df


scopus_affils_df = add_more_fuzzy_grid_info(scopus_affils_df)

# %% [markdown]
# __What have we matched?__
#
# There are 48060 affiliations.
#
# Of the 6214 that have an affiliation type:
#
# * 4587 are linked to a GRID ID and therefore have established year
# * 1627 are not linked to a GRID ID
#
# __What have we got left?__
#
# 41846 affiliations do not have an affiliation type.
#
# * 1113 have hospital
# * 1364 have school
# * 684 have university
# * 5388 have ltd
# * 1307 have limited
# * 185 have foundation
# * 1246 have trust

# %%
s = 'ltd'
scopus_affils_df[scopus_affils_df['affil_type'].isnull()]['affil_name'].str.contains(s, case=False).value_counts()
# Out:
# False    36458
# True      5388
# Name: affil_name, dtype: int64

# %%
# MORE HEURISTICS!

# %% [markdown]
# # Match Scopus against Companies House
#
# __API KEY IN CODE!__
#
# Companies House has a 600 request limit within a 5 minute period.
#
# SIC codes found [here](https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/527619/SIC07_CH_condensed_list_en.csv/preview).
#
# API information found [here](https://developer-specs.company-information.service.gov.uk/companies-house-public-data-api/reference).

# %%
CH_API_KEY = '2f182cf1-73c8-42f5-ba7f-b7b8878078fa'

# %%
# Options for using CH:
### INSTEAD OF FILTERING FOR UNMATCHED, FILTER FOR NO GRID ID
# 1) Filter unmatched Scopus affiliations and then fuzzy match against all of CH
# 2) Filter unmatched Scopus affiliations, filter CH and then fuzzy match
# 3) Filter unmatched Scopus affiliations and then use CH API to fuzzy matchtime

# %%
% timeit faster_process.extract('Biontech limited', grid_l)
% timeit faster_process.extract('Biontech limited', grid_l * 2)
# Out:
# 54.1 ms ± 955 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 109 ms ± 1.86 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
speed_per_match_item = 0.0541 / len(grid_l)
one_scopus_comparison = speed_per_match_item * 5500000
print(one_scopus_comparison)
print(one_scopus_comparison * 1000)
(one_scopus_comparison * 1000) / (60**2)
# Out:
# 40.911590815344425
# 40911.590815344425
# 11.364330782040119

# %%
scopus_affils_df[scopus_affils_df['grid_id_match'].isnull()].sample(n=10)
# Out:
#            af_id                                      affil_name  \
# 34403  113218646                            Borax Europe Limited
# 22395  100925518                                Pharmorphix Ltd.
# 27082  101210170                                     Peoplefirst
# 9887   117307307  Centre for Advanced Built Environment Research
# 16853  101499148              Institute of Development Stds. IDS
# 43413  105675615                   Denehurst Chemical Safety Ltd
# 24888  119580635                       Avlar BioVentures Limited
# 11763  116061847                 Northern Ireland Prison Service
# 18941  101295932                                   Strategem Ltd
# 41267  105995618                                       A2SP Ltd.
#
#                 affil_city                                    affil_address  \
# 34403            Guildford                       1A Guildford Business Park
# 22395  Cambridge (ex Galt)                                      Milton Road
# 27082               London                                78 Montacute Road
# 9887               Glasgow                                              NaN
# 16853                  NaN                                              NaN
# 43413                  NaN    Denehurst, Station Road, Burley in Wharfedale
# 24888            Cambridge  Compass House, Vision Park, Chivers Way, Histon
# 11763              Belfast                                  Dundonald House
# 18941           Manchester                                   Hough End Hall
# 41267              Chatham                                117 Pagitt Street
#
#       post_code                          lat_lng affil_type type_source  \
# 34403   GU2 8XG           (51.246686, -0.586932)        NaN         NaN
# 22395   CB1 0WE                              NaN        NaN         NaN
# 27082   SE6 4XQ           (51.444964, -0.033963)        NaN         NaN
# 9887        NaN                              NaN        NaN         NaN
# 16853       NaN                              NaN        NaN         NaN
# 43413       NaN                              NaN        NaN         NaN
# 24888   CB4 9ZR                              NaN        NaN         NaN
# 11763   BT4 3SU  (54.595406999999994, -5.826217)        NaN         NaN
# 18941   M21 7AZ                              NaN        NaN         NaN
# 41267   ME4 6RD            (51.374828, 0.517728)        NaN         NaN
#
#        type_confidence                                  grid_name_matches  \
# 34403                0  [(Environmental Design Solutions Limited , 85....
# 22395                0  [(ARM , 90.0, 162), (Format International Ltd,...
# 27082                0  [(GeneFirst , 70.0, 3147), (JEOL , 67.5, 761),...
# 9887                 0  [(Environment Agency, 85.5, 9), (Transport Res...
# 16853                0  [(Institute of Development Studies, 90.9090909...
# 43413                0  [(Thomas Keating Ltd, 85.5, 898), (British Ass...
# 24888                0  [(Bioven , 90.0, 4292), (Environmental Design ...
# 11763                0  [(Mines Rescue Service, 85.5, 1235), (HM Priso...
# 18941                0  [(Scimar Engineering Ltd, 85.5, 204), (Format ...
# 41267                0  [(Scimar Engineering Ltd, 85.5, 204), (Format ...
#
#        grid_name_best_score                     grid_name_best_match  \
# 34403             85.500000  Environmental Design Solutions Limited
# 22395             90.000000                                     ARM
# 27082             70.000000                               GeneFirst
# 9887              85.500000                       Environment Agency
# 16853             90.909091         Institute of Development Studies
# 43413             85.500000                       Thomas Keating Ltd
# 24888             90.000000                                  Bioven
# 11763             85.500000                     Mines Rescue Service
# 18941             85.500000                   Scimar Engineering Ltd
# 41267             85.500000                   Scimar Engineering Ltd
#
#        grid_best_match_distance_km grid_id_match
# 34403                    91.895392          None
# 22395                          NaN          None
# 27082                    86.186075          None
# 9887                           NaN          None
# 16853                          NaN          None
# 43413                          NaN          None
# 24888                          NaN          None
# 11763                   344.249254          None
# 18941                          NaN          None
# 41267                   293.507525          None

# %%
search = chwrapper.Search(access_token=CH_API_KEY)

# %%
def handle_ltd(string):
    string = string.lower()
    if 'ltd' in string.lower():
        return string.replace('ltd', 'limited')
    else:
        return string

handle_ltd('strategem Ltd')
# Out:
# 'strategem limited'

# %%
def search_CH(query):

    query = handle_ltd(query)

    resp = search.search_companies(query)
    rate_limit = resp.headers['X-Ratelimit-Limit']
    resp = resp.json()

    # Index of 0 means this is the first result - there may be more
    if not resp['items']:
        return resp['items']
    
    name = handle_ltd(resp['items'][0]['title'])
    
    if 'date_of_creation' in resp['items'][0]:
        incorp_date = resp['items'][0]['date_of_creation']
    else:
        incorp_date = ''
    
    registered_address = resp['items'][0]['address_snippet']
    company_num = resp['items'][0]['company_number']

    resp_2 = search.profile(company_num)
    rate_limit = resp_2.headers['X-Ratelimit-Limit']
    resp_2 = resp_2.json()
    
    if 'sic_codes' in resp_2:
        sic_codes = resp_2['sic_codes']
    else:
        sic_codes = []
    if 'previous_company_names' in resp_2:
        prev_names = resp_2['previous_company_names']  # list of dictionaries
    else:
        prev_names = [{'name': ''}]

    names = [handle_ltd(d['name']) for d in prev_names]
    names.insert(0, name)
    fuzzy_scores = [faster_process.extract(query, [name])[0][1] for name in names]
    
    return {'names': names,
           'incorp_date': incorp_date,
           'registered_address': registered_address,
           'sic_codes': sic_codes,
           'fuzzy_scores': fuzzy_scores}


# Testing
query = 'Roy. U. Hosp.'
results = search_CH(query)
print('Query:\n', query)
print('Different names:\n',results['names'])
print('Incorporated date:\n', results['incorp_date'])
print('Registered address:\n', results['registered_address'])
print('SIC codes:\n', results['sic_codes'])
print('Fuzzy match scores:\n', results['fuzzy_scores'])
if max(results['fuzzy_scores']) >= 90:
    print('We have a match! The highest score was {}'.format(max(results['fuzzy_scores'])))
else:
    print('No match :(')
# Out:
# Query:
#  Roy. U. Hosp.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-242-084e7efc7663> in <module>()
#      49 results = search_CH(query)
#      50 print('Query:\n', query)
# ---> 51 print('Different names:\n',results['names'])
#      52 print('Incorporated date:\n', results['incorp_date'])
#      53 print('Registered address:\n', results['registered_address'])
#
# TypeError: list indices must be integers or slices, not str

# %%
test = scopus_affils_df.copy()

# %%
def find_CH_match(x):
    
    query = x['affil_name']
    
    if pd.notnull(x['CH_match_data']):
        return x['CH_match_data']
    
    try:
        results = search_CH(query)
        if not results:  # empty list
            return 'no data'
        else:
            return results
    except:
        return np.nan

# %%
# 13 hours - not sure if due to terrible internet connection
tick = datetime.now()
test['CH_match_data'] = test.apply(lambda x: find_CH_match(x), axis=1)
tock = datetime.now()
print('Total time:', tock - tick)
# Out:
# Total time: 13:14:48.390494

# %%
test.iloc[0]['CH_match_data']
# Out:
# {'names': ['university of bath (the)', ''],
#  'incorp_date': '',
#  'registered_address': None,
#  'sic_codes': [],
#  'fuzzy_scores': [95.0, 0.0]}

# %%
test['CH_match_data'].apply(pd.Series).drop(columns=[0])
# Out:
#                           fuzzy_scores incorp_date  \
# 0                          [95.0, 0.0]
# 1                          [90.0, 0.0]
# 2                         [100.0, 0.0]
# 3                         [100.0, 0.0]
# 4                         [100.0, 0.0]
# ...                                ...         ...
# 48055                      [85.5, 0.0]  2013-04-10
# 48056        [44.107142857142854, 0.0]  2018-07-31
# 48057       [90.0, 33.096774193548384]  1966-05-24
# 48058                      [95.0, 0.0]  1911-09-07
# 48059  [75.0, 88.93617021276596, 85.5]  2002-02-14
#
#                                                    names  \
# 0                           [university of bath (the), ]
# 1                      [st mary's hospital paddington, ]
# 2                          [university college london, ]
# 3                              [king's college london, ]
# 4                       [the university of manchester, ]
# ...                                                  ...
# 48055  [innovationszentrum fur mobilitat und geselles...
# 48056              [casson conder partnership limited, ]
# 48057  [starlight xpress limited, functional design &...
# 48058          [british astronomical association(the), ]
# 48059  [artevea digital limited, simoco digital uk li...
#
#                                       registered_address       sic_codes
# 0                                                   None              []
# 1                                                   None              []
# 2                                                   None              []
# 3                                                   None              []
# 4                                                   None              []
# ...                                                  ...             ...
# 48055  8th  Floor Tower Three Houghton Street, London...              []
# 48056  470a Green Lane, Palmers Green, London, United...  [71111, 71112]
# 48057  Unit 3 Brooklands Farm Business Park, Bottle L...         [27900]
# 48058      Burlington House, Piccadilly, London, W1J 0DU  [85310, 94120]
# 48059  38  De Montfort Street, Leicester, Leicestersh...         [59113]
#
# [48060 rows x 5 columns]

# %%
# Laptop is being really slow so saving just in case something happens
os.chdir('..')
test.to_csv('scopus_affils_w_CH.csv')

# %%
test = pd.read_csv('scopus_affils_w_CH.csv')

# %%
# Loading the data back in makes it string, not dict
def to_dict(x):
    if isinstance(x, float):
        return np.nan
    elif len(x) > 20:
        return ast.literal_eval(x)
    else:
        return 'no data'

# %%
test['CH_match_data_t'] = test['CH_match_data'].apply(to_dict)

# %%
CH_data = test['CH_match_data_t'].apply(pd.Series).drop(columns=[0])
test_1 = pd.concat([test, CH_data], axis=1)

# %% [markdown]
# # Find CH matches

# %%
# Find the best CH match name and corresponding score
best_CH_score = lambda x: max(x) if isinstance(x, list) else np.nan

def best_CH_name(x):
    fuzzy_scores = x['fuzzy_scores']
    if isinstance(fuzzy_scores, list):
        max_value = max(fuzzy_scores)
        max_index = fuzzy_scores.index(max_value)
        return x['names'][max_index]
    else:
        return np.nan


test_1['best_score'] = test_1['fuzzy_scores'].apply(best_CH_score)
test_1['best_name'] = test_1.apply(lambda x: best_CH_name(x), axis=1)

# %%
test_1[(test_1['type_source'].isnull()) & (test_1['best_score'] >= 88)].shape
# Out:
# (16421, 24)

# %%
# Check unique value counts to ensure that I do not change anything else unexpectedly
test_1.type_source.value_counts()
# Out:
# exact_grid        2255
# fuzzy_grid        2006
# scopus            1629
# fuzzy_loc_grid     326
# Name: type_source, dtype: int64

# %%
# Add type_source as CH_fuzzy
def add_CH_fuzzy(x):
    source = x['type_source']
    best_score = x['best_score']
    if (pd.isnull(source)) and (best_score >= 88):
        return 'CH_fuzzy'
    else:
        return source

# %%
test_1['type_source'] = test_1.apply(lambda x: add_CH_fuzzy(x), axis=1)
test_1.type_source.value_counts()
# Out:
# CH_fuzzy          16421
# exact_grid         2255
# fuzzy_grid         2006
# scopus             1629
# fuzzy_loc_grid      326
# Name: type_source, dtype: int64

# %%
#test_1[test_1['type_source'] == 'CH_fuzzy'].sample(n=20)

# %% [markdown]
# There are sections A-U for SIC codes.
#
# * Section O: Public administration and defence; compulsory social security
# * Section P: Education
# * Section Q: Human health and social work activities
# * All other sections can fall under company

# %%
# Read in SIC codes from CH
sic_df = pd.read_csv('ch_sic_codes.csv')

# %%
sic_df.head(1)
# Out:
#    SIC Code                                        Description Section
# 0      1110  Growing of cereals (except rice), leguminous c...       A

# %%
public = sic_df[sic_df['Section'] == 'O']['SIC Code'].unique()
education = sic_df[sic_df['Section'] == 'P']['SIC Code'].unique()
health = sic_df[sic_df['Section'] == 'Q']['SIC Code'].unique()

# %%
# Add affil_type for CH matches
def add_CH_type(x):
    #print(x)
    type_source = x['type_source']
    if type_source == 'CH_fuzzy':
        # Find SIC code
        sic_codes = x['sic_codes']
        affil_type = 'company'
        # Loop through each code
        for code in sic_codes:
            code = int(code)
            # Check non-company groups
            if code in public:
                affil_type = 'public'
            elif code in education:
                affil_type = 'education'           
            elif code in health:
                affil_type = 'health'
        return affil_type
    else:
        return x['affil_type']

# %%
# Test out function on some examples
add_CH_type(test_1.iloc[47607])
# Out:
# 'education'

# %%
test_1['affil_type'] = test_1.apply(lambda x: add_CH_type(x), axis=1)

# %%
test_1.to_csv('scopus_affils.csv')

# %% [markdown]
# # Clean for analysis
#
# This was done in Excel to save time. The following steps were taken to clean the data:
#
# * Standardise affiliation types across different sources
#     * comp|hosp, comp, comp|ngov, comp|lawf (all Scopus matches) changed to company
#     * Education from GRID, coll and univ from Scopus changed to education
#     * resi|edu > education
#     * HP labs, microsoft research Cambridge, BT research lab, Schlumberger Cambridge Research, Advanced Technologies (Cambridge) Limited, GEC Research Lab, Tube Investments Research Laboratories, Saffron Walden, The Arable Group > company
#     * HR Walligford, HRWallingford, HR Wallirgford, HRWallingford, Glass Technology Services Ltd > company
#     * Facility (GRID) > resi
#     * govt, Government > government
#     * meds (medical schools) > education
#     * Healthcare, health, hosp > healthcare
#     * lawf (law companies) > company
#     * library, museum > archive
#     * milo (military) > other
#     * ngov > government
#     * ngov|resi > resi
#     * Nonprofit seems to be a mixture of resi and government - kept as is for now as there are 573 entries for this
#     * From Other: BioRegional MiniMills UK Ltd (BRMM), J.P. Morgan and others
#     * poli (policy?) to resi
#     * public from CH looks like a bit of a shambles (only 51 though)
#     * Other > other - checked that no companies were involved. Otherwise other is still a bit of a mess
#
# __Unmatched entries:__
#
# * 1003 contain school > education
# * 848 contain institut > resi
# * 389 surgery > healthcare
# * 588 medical but not biomedical > healthcare
# * 1079 contains ltd or limited > company - __there could be start ups in here - they are matched under string for now__
# * 776 contain univ > education
# * 354 contain college > education
#
# Not done:
#
# * 131 contain plc - a lot of them seemt to be good matches so I have highlighted the ones which don't seem like good matches. I haven't matched these yet because some of the registered dates are past the period of the data set. For example, Lasmo plc could be matched with Lasmo llp but Lasmo llp was registered in 2014. In this case, they are two separate companies.
# * 633 contains department or dept - hard to classify

# %% [markdown]
# # GRID Establsihed Date

# %%
os.chdir('..')

# %%
# Load data
affils = pd.read_csv('scopus_affils_clean.csv')
grid = load_grid_data(cleaning=True)
# Out:
# 7273
# 7273

# %%
# Define a function to add established date for grid matches only
def add_grid_date(x, dtype=int):
    try:
        result = grid[grid['grid_id'] == x]
        if result.shape[0] == 0:
            return np.nan
        else:
            return result.established.to_numpy(dtype=dtype)
    except:
        print('bruh', x)

# %%
add_grid_date(affils.iloc[0]['grid_id_match'])
# Out:
# array([1966])

# %%
# Apply function
affils['established_date'] = affils['grid_id_match'].apply(add_grid_date)

# %%
# Investigate start-ups
grid_start_ups = affils[(affils['affil_type'] == 'company') & (affils['established_date'] >= 1992)].copy()
grid_start_ups.loc[:, ['affil_name', 'established_date']]
# Out:
#                           affil_name established_date
# 74                       AstraZeneca           [1999]
# 149             GlaxoSmithKline plc.           [2000]
# 351             Oxford BioMedica Plc           [1995]
# 625                  BAE Systems plc           [1999]
# 641           PricewaterhouseCoopers           [1998]
# ...                              ...              ...
# 47206       Faculty Development Lead           [2014]
# 47679               Linguamatics Ltd           [2001]
# 47738                 Camfridge Ltd.           [2005]
# 47946   United BioSource Corporation           [2003]
# 47981  Mundipharma International Ltd           [2006]
#
# [343 rows x 2 columns]

# %% [markdown]
# # Established / Incorporated Date Variable

# %%
def consoliDATE(x):
    if x['affil_type'] == 'company':
        match_type = x['type_source']
        if match_type in ['exact_grid', 'fuzzy_grid', 'fuzzy_loc_grid']:
            return x['established_date'][0]
        elif match_type == 'CH_fuzzy':
            return pd.to_datetime(x['incorp_date']).year
        else:
            return np.nan
    else:
        return np.nan
    
    
consoliDATE(affils.iloc[33])
# Out:
# 2016

# %%
affils['est_inc_date'] = affils.apply(lambda x: consoliDATE(x), axis=1)

# %% [markdown]
# # Companies Matched Through Scopus
#
# Because there is no established date for companies that were matched through Scopus, I need to check these for their Companies House and GRID matches.

# %%
affils[(affils['affil_type'] == 'company') & (affils['type_source'] == 'scopus')]
# Out:
#        Unnamed: 0  Unnamed: 0.1     af_id  \
# 25             25            25  60006769
# 101           101           101  60005889
# 128           128           128  60015695
# 136           136           136  60010098
# 210           210           210  60110398
# ...           ...           ...       ...
# 46851       46851         46851  60100629
# 47055       47055         47055  60121174
# 47248       47248         47248  60112368
# 47466       47466         47466  60158095
# 47853       47853         47853  60122138
#
#                                   affil_name       affil_city  \
# 25                             RSK ADAS Ltd.           Helsby
# 101                                 LGC Ltd.       Teddington
# 128                            Kodak Limited  Hemel Hempstead
# 136                       GV Instruments Ltd       Manchester
# 210    Hewlett Packard Laboratories, Bristol          Bristol
# ...                                      ...              ...
# 46851                         ARTVPS Limited        Cambridge
# 47055         Blue Bear Systems Research Ltd           Oakley
# 47248                            KWS UK Ltd.          Royston
# 47466            David Marlin Consulting Ltd  Bury St Edmunds
# 47853                           iQur Limited           London
#
#                                            affil_address post_code  \
# 25                        Spring Lodge, 172 Chester Road   WA6 0AR
# 101                                          Queens Road  TW11 0LY
# 128                                         Station Road    HP11JU
# 136                                           Crewe Road   M23 9BE
# 210                       Long Down Avenue Stoke Gifford   BS348QZ
# ...                                                  ...       ...
# 46851           St John's Innovation Centre, Cowley Road    CB40WS
# 47055                   4 Highfield Parc, Highfield Road  MK43 7TA
# 47248                         56 Church Street, Thriplow   SG8 7RE
# 47466                                 Unit 2A Chase Road  IP32 6NT
# 47853  The London Bioscience Innovation Centre, 2 Roy...   NW1 0NH
#
#                                lat_lng affil_type type_source  \
# 25     (53.274328000000004, -2.768207)    company      scopus
# 101             (51.423929, -0.341471)    company      scopus
# 128                                NaN    company      scopus
# 136              (53.404701, -2.29745)    company      scopus
# 210                                NaN    company      scopus
# ...                                ...        ...         ...
# 46851                              NaN    company      scopus
# 47055           (52.175458, -0.519696)    company      scopus
# 47248   (52.099726000000004, 0.104675)    company      scopus
# 47466   (52.268046999999996, 0.699194)    company      scopus
# 47853            (51.53613, -0.133409)    company      scopus
#
#        type_confidence                                  grid_name_matches  \
# 25                  10  [('Scimar Engineering Ltd', 85.5, 204), ('Form...
# 101                 10  [('Scimar Engineering Ltd', 85.5, 204), ('Form...
# 128                 10  [('Kodak ', 90.0, 778), ('Beta Technology Limi...
# 136                 10  [('Catalyst Health Economics Consultants Ltd',...
# 210                 10  [('Hewlett-Packard ', 90.0, 155), ('University...
# ...                ...                                                ...
# 46851               10  [('Beta Technology Limited', 85.5, 196), ('Env...
# 47055               10  [('Blue Bear ', 90.0, 3109), ('BAE Systems ', ...
# 47248               10  [('KWS ', 90.0, 782), ('Cancer Research UK', 8...
# 47466               10  [('Catalyst Health Economics Consultants Ltd',...
# 47853               10  [('iQur ', 90.0, 1874), ('Beta Technology Limi...
#
#        grid_name_best_score                       grid_name_best_match  \
# 25                     85.5                     Scimar Engineering Ltd
# 101                    85.5                     Scimar Engineering Ltd
# 128                    90.0                                     Kodak
# 136                    85.5  Catalyst Health Economics Consultants Ltd
# 210                    90.0                           Hewlett-Packard
# ...                     ...                                        ...
# 46851                  85.5                    Beta Technology Limited
# 47055                  90.0                                 Blue Bear
# 47248                  90.0                                       KWS
# 47466                  85.5  Catalyst Health Economics Consultants Ltd
# 47853                  90.0                                      iQur
#
#        grid_best_match_distance_km grid_id_match  \
# 25                      290.531361           NaN
# 101                     237.398027           NaN
# 128                            NaN           NaN
# 136                     237.380673           NaN
# 210                            NaN           NaN
# ...                            ...           ...
# 46851                          NaN           NaN
# 47055                     3.121020           NaN
# 47248                     0.287248           NaN
# 47466                   106.361296           NaN
# 47853                     0.019026           NaN
#
#                                            CH_match_data  \
# 25     {'names': ['rsk adas limited', ''], 'incorp_da...
# 101    {'names': ['lgc limited', 'lgc (teddington) li...
# 128    {'names': ['kodak limited', ''], 'incorp_date'...
# 136    {'names': ['g v instruments limited', 'level s...
# 210    {'names': ['hewlett - packard limited', ''], '...
# ...                                                  ...
# 46851  {'names': ['art vps limited', 'legislator 1584...
# 47055  {'names': ['blue bear systems research limited...
# 47248  {'names': ['kws uk limited', 'cpb twyford limi...
# 47466  {'names': ['david marlin consulting limited', ...
# 47853  {'names': ['iqur limited', 'hepcgen limited', ...
#
#                                          CH_match_data_t  \
# 25     {'names': ['rsk adas limited', ''], 'incorp_da...
# 101    {'names': ['lgc limited', 'lgc (teddington) li...
# 128    {'names': ['kodak limited', ''], 'incorp_date'...
# 136    {'names': ['g v instruments limited', 'level s...
# 210    {'names': ['hewlett - packard limited', ''], '...
# ...                                                  ...
# 46851  {'names': ['art vps limited', 'legislator 1584...
# 47055  {'names': ['blue bear systems research limited...
# 47248  {'names': ['kws uk limited', 'cpb twyford limi...
# 47466  {'names': ['david marlin consulting limited', ...
# 47853  {'names': ['iqur limited', 'hepcgen limited', ...
#
#                                             fuzzy_scores incorp_date  \
# 25                                          [100.0, 0.0]  18/11/2016
# 101                            [100.0, 85.5, 85.5, 85.5]  18/11/1994
# 128                                         [100.0, 0.0]  1898-11-15
# 136               [97.77777777777777, 63.63636363636363]  21/05/2002
# 210                                          [75.0, 0.0]  24/04/1961
# ...                                                  ...         ...
# 46851                          [96.55172413793103, 85.5]  14/06/2002
# 47055                                       [100.0, 0.0]  27/10/1999
# 47248  [100.0, 63.33333333333332, 85.5, 63.3333333333...  10/08/1981
# 47466                                       [100.0, 0.0]  08/12/2006
# 47853                                [100.0, 70.0, 85.5]  13/02/2003
#
#                                                    names  \
# 25                              ['rsk adas limited', '']
# 101    ['lgc limited', 'lgc (teddington) limited', 'l...
# 128                                ['kodak limited', '']
# 136    ['g v instruments limited', 'level services li...
# 210                    ['hewlett - packard limited', '']
# ...                                                  ...
# 46851     ['art vps limited', 'legislator 1584 limited']
# 47055         ['blue bear systems research limited', '']
# 47248  ['kws uk limited', 'cpb twyford limited', 'cam...
# 47466            ['david marlin consulting limited', '']
# 47853  ['iqur limited', 'hepcgen limited', 'inputpoun...
#
#                                       registered_address  sic_codes  \
# 25     Spring Lodge, 172 Chester Road, Helsby, Cheshi...  ['74901']
# 101         Queens Road, Teddington, Middlesex, TW11 0LY  ['74909']
# 128    Building 8  Croxley Green Business Park, Hatte...  ['58190']
# 136    3rd Floor, 1 Ashley Road, Altrincham, Cheshire...  ['26511']
# 210    Ground Floor, 210 Wharfedale Road, Winnersh Tr...  ['62090']
# ...                                                  ...        ...
# 46851  St John's Innovation Centre, Cowley Road, Camb...  ['62012']
# 47055  Richmond House, Walkern Road, Stevenage, Hertf...  ['82990']
# 47248  56  Church Street, Thriplow, Royston, Hertford...  ['01110']
# 47466  Streets Whitmarsh Sterland, 62 Hills Road, Cam...  ['82990']
# 47853  The London Bioscience Innovation Centre, 2 Roy...  ['72110']
#
#        best_score                           best_name established_date  \
# 25     100.000000                    rsk adas limited              NaN
# 101    100.000000                         lgc limited              NaN
# 128    100.000000                       kodak limited              NaN
# 136     97.777778             g v instruments limited              NaN
# 210     75.000000           hewlett - packard limited              NaN
# ...           ...                                 ...              ...
# 46851   96.551724                     art vps limited              NaN
# 47055  100.000000  blue bear systems research limited              NaN
# 47248  100.000000                      kws uk limited              NaN
# 47466  100.000000     david marlin consulting limited              NaN
# 47853  100.000000                        iqur limited              NaN
#
#        est_inc_date
# 25              NaN
# 101             NaN
# 128             NaN
# 136             NaN
# 210             NaN
# ...             ...
# 46851           NaN
# 47055           NaN
# 47248           NaN
# 47466           NaN
# 47853           NaN
#
# [717 rows x 27 columns]

# %%
uk = '(United Kingdom)'
grid['Name'] = grid['Name'].apply(lambda x: x.replace(uk, '') if uk in x else x)

# %%
def consoliDATE_scopus(x):
    
    if (x['affil_type'] == 'company') and (x['type_source'] == 'scopus'):
        # Check GRID match score
        if x['grid_name_best_score'] >= 90:
            # Get GRID established date
            result = grid[grid['Name'] == x['grid_name_best_match']]
            print(result)
            if result.shape[0] > 0:
                if result.shape[0] != 1:
                    print(result)
                    print(result.established.to_numpy()[0])
                return result.established.to_numpy()[0]
        # Check CH match score
        elif x['best_score'] >= 90:
            return pd.to_datetime(x['incorp_date']).year
        else:
            #print('not good enough')
            return np.nan
    else:
        return x['est_inc_date']
        

consoliDATE_scopus(affils.iloc[46267])
# Out:
# nan

# %%
affils['est_inc_date'] = affils.apply(lambda x: consoliDATE_scopus(x), axis=1)

# %%
print('Potential companies that do not have an incorporation date (ignoring string matches):')
print(affils[(affils['affil_type'] == 'company') & (affils['est_inc_date'].isnull()) & 
      (affils['type_source'] != 'string')].shape[0])
print('Potential companies that do not have an est/inc date and were matched through string matching:')
print(affils[(affils['affil_type'] == 'company') & (affils['est_inc_date'].isnull()) & 
      (affils['type_source'] == 'string')].shape[0])
# Out:
# Potential companies that do not have an incorporation date (ignoring string matches):
# 452
# Potential companies that do not have an est/inc date and were matched through string matching:
# 1079

# %%
columns = ['affil_name', 'grid_name_best_score', 'grid_name_best_match', 'best_score', 'best_name']
affils[(affils['affil_type'] == 'company') & (affils['est_inc_date'].isnull()) & 
      (affils['type_source'] == 'string')].loc[:, columns].shape[0]
# Out:
# 1079

# %% [markdown]
# # Additional Matches
#
# There are probably more matches in string that could be made by removing ltd, limited, and plc. However, I will stick with what I've got for now.

# %% [markdown]
# # Latitude and Longitude
#
# Are there are any more institutions that can have lat_lng included that aren't already?
#
# Not the most important part at the moment!

# %%
print('Number of institutions without affiliation type:')
print(affils[affils['affil_type'].isnull()].shape[0])

print('Number of institutions WITH affiliation type but no lat, lng:')
print(affils[(affils['lat_lng'].isnull()) & (affils['affil_type'].notnull())].shape[0])
# Out:
# Number of institutions without affiliation type:
# 20388
# Number of institutions WITH affiliation type but no lat, lng:
# 12843

# %%
affils[(affils['lat_lng'].isnull()) & (affils['affil_type'].notnull())].type_source.value_counts()
# Out:
# CH_fuzzy      7752
# string        2953
# fuzzy_grid     870
# exact_grid     676
# scopus         592
# Name: type_source, dtype: int64

# %%
# How many have CH registered address?
print(affils[(affils['lat_lng'].isnull()) & (affils['type_source'] == 'CH_fuzzy') & 
       (affils['registered_address'].notnull())].shape[0])
affils[(affils['lat_lng'].isnull()) & (affils['type_source'] == 'CH_fuzzy') & 
       (affils['registered_address'].notnull())].sample(n=1)
# Out:
# 7560
#       Unnamed: 0  Unnamed: 0.1      af_id affil_name affil_city affil_address  \
# 4326        4326          4326  115984584    Enfield        NaN           NaN
#
#      post_code lat_lng affil_type type_source  type_confidence  \
# 4326       NaN     NaN    company    CH_fuzzy                0
#
#                                       grid_name_matches  grid_name_best_score  \
# 4326  [('Glenfield Hospital', 90.0, 308), ('Barnet E...                  90.0
#
#      grid_name_best_match  grid_best_match_distance_km grid_id_match  \
# 4326   Glenfield Hospital                          NaN           NaN
#
#                                           CH_match_data  \
# 4326  {'names': ['enfield limited', ''], 'incorp_dat...
#
#                                         CH_match_data_t fuzzy_scores  \
# 4326  {'names': ['enfield limited', ''], 'incorp_dat...  [90.0, 0.0]
#
#      incorp_date                    names  \
# 4326  26/03/2001  ['enfield limited', '']
#
#                                      registered_address           sic_codes  \
# 4326  58 Brookside Crescent, Cuffley, Hertfordshire,...  ['68209', '69202']
#
#       best_score        best_name established_date  est_inc_date
# 4326        90.0  enfield limited              NaN        2001.0

# %%
def locate(x):
    if ()

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent='aidan')

# %%
location = geolocator.geocode(affils.iloc[4326]['registered_address'])

# %%
location.latitude, location.longitude
# Out:
# (51.7154379, -0.1121931)

# %% [markdown]
# # Save Data

# %%
affils.to_csv('scopus_affils.csv')

# %% [markdown]
# # Save Clean Version

# %%
columns = ['af_id', 'affil_name', 'affil_city', 'post_code', 'lat_lng', 'affil_type', 'type_source', 
           'grid_id_match', 'est_inc_date']
clean = affils.loc[:, columns].copy()
clean.to_csv('scopus_affils_clean.csv')

# %%
clean
# Out:
#            af_id                        affil_name  affil_city post_code  \
# 0       60030480                University of Bath        Bath   BA2 7AY
# 1       60022871                St Mary's Hospital      London    W2 1NY
# 2       60022148         University College London      London  WC1E 6BT
# 3       60011520             King's College London      London  WC2R 2LS
# 4       60003771      The University of Manchester  Manchester   M13 9PL
# ...          ...                               ...         ...       ...
# 48055  108616326          Lntervet Innovation GmbH         NaN       NaN
# 48056  107918540           Conder Brow Observatory   Lancaster   LAI 1XD
# 48057  106599190                  Starlight Xpress   Berkshire   SL6 3LA
# 48058  106598998  British Astronomical Association     Reading   RG6 4AZ
# 48059  106598714        Simoco Digital Systems Ltd   Cambridge   CB4 1GR
#
#                                  lat_lng  affil_type type_source  \
# 0                  (51.38044, -2.330673)   education  exact_grid
# 1                 (51.516969, -0.173569)  healthcare  exact_grid
# 2      (51.523569, -0.13242400000000001)   education  exact_grid
# 3                 (51.511612, -0.116253)   education  exact_grid
# 4       (53.467925, -2.2332240000000003)   education  fuzzy_grid
# ...                                  ...         ...         ...
# 48055                                NaN         NaN         NaN
# 48056                                NaN         NaN         NaN
# 48057             (51.483702, -0.733949)     company    CH_fuzzy
# 48058              (51.420429, -0.94514)   Nonprofit  exact_grid
# 48059                                NaN     company    CH_fuzzy
#
#        grid_id_match  est_inc_date
# 0        grid.7340.0           NaN
# 1      grid.426467.5           NaN
# 2      grid.83440.3b           NaN
# 3      grid.13097.3c           NaN
# 4        grid.5379.8           NaN
# ...              ...           ...
# 48055            NaN           NaN
# 48056            NaN           NaN
# 48057            NaN        1966.0
# 48058  grid.508416.e           NaN
# 48059            NaN        2002.0
#
# [48060 rows x 9 columns]
